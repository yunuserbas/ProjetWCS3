# %%
#public ; attention au filtre
#https://www.herault-data.fr/api/records/1.0/search/?dataset=parkingtpsreel_modele0&q=&rows=16&facet=name&facet=commune&facet=domanialit&facet=proprietai&refine.commune=Montpellier&refine.domanialit=Public

# %% [markdown]
# titre:   PARKINGS - DISPONIBILITÉ DES PLACES DANS LES PARKINGS EN OUVRAGE DE MONTPELLIER MÉDITERRANÉE MÉTROPOLE
#
# https://www.herault-data.fr/explore/dataset/parkingtpsreel_modele0/api/?rows=16&refine.commune=Montpellier&refine.domanialit=Public

# %%
import pandas as pd
import json
import pandas as pd
import requests
link='https://www.herault-data.fr/api/records/1.0/search/?dataset=parkingtpsreel_modele0&q=&rows=16&facet=name&facet=commune&facet=domanialit&facet=proprietai&refine.commune=Montpellier&refine.domanialit=Public'
r = requests.get(link)
# You can access to the text content with this function
data=r.text

# %%
data = json.loads(r.text)
print(data)
# Out:
# {'nhits': 16, 'parameters': {'dataset': 'parkingtpsreel_modele0', 'rows': 16, 'start': 0, 'facet': ['name', 'commune', 'domanialit', 'proprietai'], 'format': 'json', 'timezone': 'UTC'}, 'records': [{'datasetid': 'parkingtpsreel_modele0', 'recordid': 'ee5fc3ac1be0f7ff8dfee9503e960c3a0ed0faf8', 'fields': {'geometry': {'coordinates': [3.9178495, 43.6049537690577], 'type': 'Point'}, 'total': 1500, 'proprietai': 'Montpellier Méditerranée Métropole', 'domanialit': 'Public', 'free': 505, 'adresse': 'rue Georges Melies - 34172 Montpellier', 'pourcentage_de_places_disponibles': 33, 'code_insee': '34172', 'coord': '43.6049537690577, 3.9178495', 'name': 'Circé Odysseum', 'datetime': '2022-11-23T13:07:43+00:00', 'dateinfo': '2022-11-23 à 14:07:43+01:00', 'commune': 'Montpellier', 'geo_point_2d': [43.6049537690577, 3.9178495]}, 'geometry': {'type': 'Point', 'coordinates': [3.9178495, 43.6049537690577]}, 'record_timestamp': '2022-11-23T13:10:22.841Z'}, {'datasetid': 'parkingtpsreel_modele0', 'reco
# ...

# %%
# And you can import JSON object to pandas
pd.json_normalize(r.json())
# Out:
#    nhits                                            records  \
# 0     16  [{'datasetid': 'parkingtpsreel_modele0', 'reco...
#
#                                         facet_groups      parameters.dataset  \
# 0  [{'name': 'name', 'facets': [{'name': 'Antigon...  parkingtpsreel_modele0
#
#    parameters.rows  parameters.start                         parameters.facet  \
# 0               16                 0  [name, commune, domanialit, proprietai]
#
#   parameters.format parameters.timezone
# 0              json                 UTC

# %%
df=pd.json_normalize(data["records"],meta='fields')
df
# Out:
#                  datasetid                                  recordid  \
# 0   parkingtpsreel_modele0  ee5fc3ac1be0f7ff8dfee9503e960c3a0ed0faf8
# 1   parkingtpsreel_modele0  9c548c7d827f39644353319d425dc6a688b30f6b
# 2   parkingtpsreel_modele0  31e89fbb6dff5463d6b7feb2814cb69bdf6efa9d
# 3   parkingtpsreel_modele0  f7226e3693f5b6faf248c910cdfad89e410ccc59
# 4   parkingtpsreel_modele0  1ca126e9eea3e440c0aba7d56697552775f12cbc
# 5   parkingtpsreel_modele0  430c48db345c75d68acab5b6e58e2a0be0315c09
# 6   parkingtpsreel_modele0  0f103066aaa4ef64fc50afdae00983439cec3ec5
# 7   parkingtpsreel_modele0  ee3f5ae6965e33b3b42bb91ece6169e4de78ba78
# 8   parkingtpsreel_modele0  de8717981b09ca14ec3fd22ad348092f7ed94945
# 9   parkingtpsreel_modele0  de32614656e3dcbd7993c5aab90eab1c4550bc0f
# 10  parkingtpsreel_modele0  d74bdb78aa4197fb7110277e7cce1f79be8d8373
# 11  parkingtpsreel_modele0  4215f3daaba9065eba067a73fa0250fc16f427de
# 12  parkingtpsreel_modele0  f5c0a2c3b169bd05a3acf16e8a85ea1e10528edd
# ...

# %%
df[['lat','lon']]= df['geometry.coordinates'].to_list()
df[['lat','lon']]=df[['lat','lon']].astype(float)
df
# Out:
#                  datasetid                                  recordid  \
# 0   parkingtpsreel_modele0  ee5fc3ac1be0f7ff8dfee9503e960c3a0ed0faf8
# 1   parkingtpsreel_modele0  9c548c7d827f39644353319d425dc6a688b30f6b
# 2   parkingtpsreel_modele0  31e89fbb6dff5463d6b7feb2814cb69bdf6efa9d
# 3   parkingtpsreel_modele0  f7226e3693f5b6faf248c910cdfad89e410ccc59
# 4   parkingtpsreel_modele0  1ca126e9eea3e440c0aba7d56697552775f12cbc
# 5   parkingtpsreel_modele0  430c48db345c75d68acab5b6e58e2a0be0315c09
# 6   parkingtpsreel_modele0  0f103066aaa4ef64fc50afdae00983439cec3ec5
# 7   parkingtpsreel_modele0  ee3f5ae6965e33b3b42bb91ece6169e4de78ba78
# 8   parkingtpsreel_modele0  de8717981b09ca14ec3fd22ad348092f7ed94945
# 9   parkingtpsreel_modele0  de32614656e3dcbd7993c5aab90eab1c4550bc0f
# 10  parkingtpsreel_modele0  d74bdb78aa4197fb7110277e7cce1f79be8d8373
# 11  parkingtpsreel_modele0  4215f3daaba9065eba067a73fa0250fc16f427de
# 12  parkingtpsreel_modele0  f5c0a2c3b169bd05a3acf16e8a85ea1e10528edd
# ...

# %%
df1=df[['record_timestamp','fields.geometry.type','fields.total','fields.proprietai','fields.domanialit','fields.free','fields.free','fields.adresse','fields.pourcentage_de_places_disponibles','fields.name','fields.datetime','fields.dateinfo','fields.commune','geometry.coordinates','lat','lon']]
df1
# Out:
#             record_timestamp fields.geometry.type  fields.total  \
# 0   2022-11-23T13:10:22.841Z                Point          1500
# 1   2022-11-23T13:10:56.332Z                Point           570
# 2   2022-11-23T13:10:11.568Z                Point           593
# 3    2022-11-23T13:10:15.34Z                Point           656
# 4   2022-11-23T13:10:27.021Z                Point           328
# 5    2022-11-23T13:10:37.15Z                Point           255
# 6   2022-11-23T13:10:39.419Z                Point           627
# 7   2022-11-23T13:10:24.921Z                Point           395
# 8    2022-11-23T13:10:54.48Z                Point          1911
# 9   2022-11-23T13:10:06.651Z                Point           774
# 10  2022-11-23T13:10:08.851Z                Point           450
# 11  2022-11-23T13:10:00.499Z                Point           239
# 12  2022-11-23T13:10:52.244Z                Point           450
# 13  2022-11-23T13:10:13.248Z                Point           434
# ...

# %%
import folium
map = folium.Map(location=[df1['lon'].mean(), df1['lat'].mean()],
                 zoom_start=15,
                 control_scale=True)

for index, row in df1.iterrows():
    folium.Marker([row['lon'], row['lat']], popup = row['fields.adresse']).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
from sqlalchemy import create_engine

import pymysql

import pandas as pd

import schedule
import time


def  load_data():
    link='https://www.herault-data.fr/api/records/1.0/search/?dataset=parkingtpsreel_modele0&q=&rows=16&facet=name&facet=commune&facet=domanialit&facet=proprietai&refine.commune=Montpellier&refine.domanialit=Public'
    r = requests.get(link)
    # You can access to the text content with this function
    data = json.loads( r.text)
    # And you can import JSON object to pandas
    pd.json_normalize(r.json())
    df_parking=pd.json_normalize(data["records"],meta='fields')
    df_parking[['lat','lon']]= df_parking['geometry.coordinates'].to_list()
    df_parking[['lat','lon']]=df_parking[['lat','lon']].astype(float)
    parking=df_parking[['record_timestamp','fields.total','fields.proprietai','fields.free','fields.adresse','fields.pourcentage_de_places_disponibles','fields.name','fields.dateinfo','lat','lon']]
    parking['record_timestamp']=parking.loc[:,'record_timestamp'].apply(lambda x: x.split('.')[0].replace('T',' '))
    
    tableName   = "parking"
    dataFrame   = parking
    dataframe   = pd.DataFrame(data = parking)
    sqlEngine       = create_engine('mysql+pymysql://yunus:Gs_16101952@127.0.0.1/projetapi', pool_recycle=3600)
    dbConnection    = sqlEngine.connect()
    try:
                       frame = dataFrame.to_sql(tableName, dbConnection, if_exists='replace');
    except ValueError as vx:
                       print(vx)
    except Exception as ex:
                       print(ex)
    else:
                       print("Table %s)created successfully."%dataframe);
    finally:
                       dbConnection.close()

# %%
load_data()
# Out:
# Table        record_timestamp  fields.total                   fields.proprietai  \
# 0   2022-11-23 13:20:09           450  Montpellier Méditerranée Métropole
# 1   2022-11-23 13:20:14           434                Ville de Montpellier
# 2   2022-11-23 13:20:40           255  Montpellier Méditerranée Métropole
# 3   2022-11-23 13:20:42           627  Montpellier Méditerranée Métropole
# 4   2022-11-23 13:21:01           570                Ville de Montpellier
# 5   2022-11-23 13:20:26           395  Montpellier Méditerranée Métropole
# 6   2022-11-23 13:20:55          1911                Ville de Montpellier
# 7   2022-11-23 13:20:00           239                Ville de Montpellier
# 8   2022-11-23 13:20:16           656                Ville de Montpellier
# 9   2022-11-23 13:20:29           328  Montpellier Méditerranée Métropole
# 10  2022-11-23 13:20:32           283  Montpellier Méditerranée Métropole
# 11  2022-11-23 13:20:06           774                Ville de Montpellier
# ...

# %%
schedule.every(10).minutes.do(load_data)
# Out:
# Every 10 minutes do load_data() (last run: [never], next run: 2022-11-23 14:34:19)

# %%
while True:
    schedule.run_pending()
    time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [48], in <cell line: 2>()
#       1 while True:
#       2     schedule.run_pending()
# ----> 3     time.sleep(1)
#
# KeyboardInterrupt:
