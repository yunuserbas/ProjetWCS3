# %%
import requests
import json
import pandas as pd

url = "https://www.herault-data.fr/api/records/1.0/search/?dataset=tam_mmm_velomag&q=&lang=fr&rows=56&facet=name&facet=commune&refine.commune=Montpellier"
page = requests.get(url)
data = page.json()

# %%
df = pd.json_normalize(data['records']).drop(['datasetid','recordid'], axis=1)

df.rename(columns={'fields.pourcentage_de_velos_restants': 'pourcentage_de_velos_restants', 'fields.num_docks_available': 'num_docks_available', 'fields.coord': 'coord',
                   'fields.commune': 'commune', 'fields.capacity': 'capacity', 'fields.num_bikes_available': 'num_bikes_available', 'fields.geopoint': 'geopoint',
                   'fields.name': 'adresse', 'fields.num_bikes_disabled': 'num_bikes_disabled', 'fields.num_bikes_available': 'num_bikes_available'}, inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [35], in <cell line: 1>()
# ----> 1 df = pd.json_normalize(data['records']).drop(['datasetid','recordid'], axis=1)
#       3 df.rename(columns={'fields.pourcentage_de_velos_restants': 'pourcentage_de_velos_restants', 'fields.num_docks_available': 'num_docks_available', 'fields.coord': 'coord',
#       4                    'fields.commune': 'commune', 'fields.capacity': 'capacity', 'fields.num_bikes_available': 'num_bikes_available', 'fields.geopoint': 'geopoint',
#       5                    'fields.name': 'adresse', 'fields.num_bikes_disabled': 'num_bikes_disabled', 'fields.num_bikes_available': 'num_bikes_available'}, inplace=True)
#       6 df
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
# ...

# %%
data['records'][0]["fields"]['geopoint']

# %%
pip install folium

# %%
#import folium
m=folium.Map(location=[43.605366, 3.881346], zoom_start=12.5)
m

for i in range(0, len(df)):
  if df.loc[i, "pourcentage_de_velos_restants"] == 0:
    folium.Marker(location=df.loc[i, "geopoint"], popup=df.loc[i, "adresse"], icon=folium.Icon(color="black" ,icon="pushpin")).add_to(m)
m

for i in range(0, len(df)):
  if df.loc[i, "pourcentage_de_velos_restants"] <= 30 and df.loc[i, "pourcentage_de_velos_restants"] != 0:
    folium.Marker(location=df.loc[i, "geopoint"], popup=df.loc[i, "adresse"], icon=folium.Icon(color="red" ,icon="pushpin")).add_to(m)
m

for i in range(0, len(df)):
  if df.loc[i, "pourcentage_de_velos_restants"] > 30 and df.loc[i, "pourcentage_de_velos_restants"] <= 70:
    folium.Marker(location=df.loc[i, "geopoint"], popup=df.loc[i, "adresse"], icon=folium.Icon(color="orange" ,icon="pushpin")).add_to(m)
m

for i in range(0, len(df)):
  if df.loc[i, "pourcentage_de_velos_restants"] > 70 and df.loc[i, "pourcentage_de_velos_restants"] <= 99:
    folium.Marker(location=df.loc[i, "geopoint"], popup=df.loc[i, "adresse"], icon=folium.Icon(color="green" ,icon="pushpin")).add_to(m)
m

for i in range(0, len(df)):
  if df.loc[i, "pourcentage_de_velos_restants"] == 100:
    folium.Marker(location=df.loc[i, "geopoint"], popup=df.loc[i, "adresse"], icon=folium.Icon(color="blue" ,icon="pushpin")).add_to(m)
m

# %%
def lat(list):
    latitude = list[0]
    return latitude

# %%
def lon(list):
    longitude = list[1]
    return longitude

# %%
df['latitude'] = df["geopoint"].apply(lat)
df['longitude'] = df["geopoint"].apply(lon)

# %%
def date(dt):
    return dt.split('.')[0].replace('T',' ')

dt = "2022-11-17T09:30:09.678Z"
date(dt)
# Out:
# '2022-11-17 09:30:09'

# %%
df['record_timestamp'] = df['record_timestamp'].apply(date)

# %%
data_velo = df[[ 'adresse', 'num_docks_available', 'capacity', 'num_bikes_available', 'num_bikes_disabled', 'pourcentage_de_velos_restants', 'latitude', 'longitude', 'record_timestamp']]
data_velo
# Out:
#                                  adresse  num_docks_available  capacity  \
# 0                                Comédie                    6        24
# 1                           Emile Combes                    2         8
# 2                        Antigone centre                    5        16
# 3                            Saint-Denis                    7         8
# 4                                Richter                    4        16
# 5                               Voltaire                    5         8
# 6                                Malbosc                    6         8
# 7                         FacdesSciences                    5        24
# 8                         Fac de Lettres                    7        16
# 9   Parvis Jules Ferry - Gare Saint-Roch                    7         8
# 10                        Hôtel de Ville                    6        16
# 11         Place Albert 1er - St Charles                   19        27
# ...

# %%
from sqlalchemy import create_engine

import pymysql

import pandas as pd

import schedule
import time


def  load_data():
    link ="https://www.herault-data.fr/api/records/1.0/search/?dataset=tam_mmm_velomag&q=&lang=fr&rows=56&facet=name&facet=commune&refine.commune=Montpellier"
    # This function gets the file content from the URL
    r = requests.get(link)
    # You can access to the text content with this function
    data=json.loads( r.text)
    pd.json_normalize(r.json())
    df=pd.json_normalize(data["records"],meta='fields')
    df = pd.json_normalize(data['records']).drop(['datasetid','recordid'], axis=1)
    df.rename(columns={'fields.pourcentage_de_velos_restants': 'pourcentage_de_velos_restants', 'fields.num_docks_available': 'num_docks_available', 'fields.coord': 'coord',
                   'fields.commune': 'commune', 'fields.capacity': 'capacity', 'fields.num_bikes_available': 'num_bikes_available', 'fields.geopoint': 'geopoint',
                   'fields.name': 'adresse', 'fields.num_bikes_disabled': 'num_bikes_disabled', 'fields.num_bikes_available': 'num_bikes_available'}, inplace=True)
    df["latitude"] = df["geopoint"].apply(lat)
    df["longitude"] = df["geopoint"].apply(lon)
    df['record_timestamp'] = df['record_timestamp'].apply(date)
    data_velo = df[[ 'adresse', 'num_docks_available', 'capacity', 'num_bikes_available', 'num_bikes_disabled', 'pourcentage_de_velos_restants', 'latitude', 'longitude', 'record_timestamp']]
    
    
    tableName   = "data_velo"
    dataFrame   =data_velo
    sqlEngine       = create_engine('mysql+pymysql://name:password@127.0.0.1/projetapi?charset=utf8mb4', max_overflow=20)
    dbConnection    = sqlEngine.connect()
    try:
                       frame           = dataFrame.to_sql(tableName, dbConnection, if_exists='replace');
    except ValueError as vx:
                       print(vx)
    except Exception as ex:
                       print(ex)
    else:
                       print("Table %s)created successfully."%tableName);
    finally:
                       dbConnection.close()

# %%
load_data()
# Out:
# Table data_velo)created successfully.

# %%
schedule.every(10).minutes.do(load_data)
# Out:
# Every 10 minutes do load_data() (last run: [never], next run: 2022-11-23 12:10:51)

# %%
while True:
    schedule.run_pending()
    time.sleep(1)
# Out:
# Table data_velo)created successfully.
