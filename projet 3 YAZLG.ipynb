# %%
import schedule
import time
import requests
import json
import pandas as pd

# %%
link ="https://www.herault-data.fr/api/records/1.0/search/?dataset=tam_mmm_velomag&q=&lang=fr&rows=56&facet=name&facet=commune&refine.commune=Montpellier"
# This function gets the file content from the URL
r = requests.get(link)
# You can access to the text content with this function
data=json.loads( r.text)
pd.json_normalize(r.json())
df=pd.json_normalize(data["records"],meta='fields')
df1=df[['fields.name','record_timestamp','geometry.coordinates','fields.capacity','fields.num_bikes_available','fields.num_docks_available','fields.pourcentage_de_velos_restants']]
df1['record_timestamp']=df1.loc[:,'record_timestamp'].apply(lambda x: x.split('.')[0].replace('T',' '))
df1[['lat','lon']]= df1['geometry.coordinates'].to_list()
df1[['lat','lon']]=df1[['lat','lon']].astype(float)
df1.drop('geometry.coordinates',inplace=True,axis=1)
# Out:
# C:\Users\ziedj\AppData\Local\Temp\ipykernel_17308\2357181274.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['record_timestamp']=df1.loc[:,'record_timestamp'].apply(lambda x: x.split('.')[0].replace('T',' '))
# C:\Users\ziedj\AppData\Local\Temp\ipykernel_17308\2357181274.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[['lat','lon']]= df1['geometry.coordinates'].to_list()
# C:\Users\ziedj\AppData\Local\Temp\ipykernel_17308\2357181274.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[['lat','lon']]= df1['geometry.coordinates'].to_list()
# C:\Users\ziedj\AppData\Local\Temp\ipykernel_17308\2357181274.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[['lat','lon']]=df1[['lat','lon']].astype(float)
# C:\Users\ziedj\AppData\Local\Temp\ipykernel_17308\2357181274.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop('geometry.coordinates',inplace=True,axis=1)

# %%
from sqlalchemy import create_engine

import pymysql

import pandas as pd

# %%
def  load_data():
    link ="https://www.herault-data.fr/api/records/1.0/search/?dataset=tam_mmm_velomag&q=&lang=fr&rows=56&facet=name&facet=commune&refine.commune=Montpellier"
    # This function gets the file content from the URL
    r = requests.get(link)
    # You can access to the text content with this function
    data=json.loads( r.text)
    pd.json_normalize(r.json())
    df=pd.json_normalize(data["records"],meta='fields')
    df1=df[['fields.name','record_timestamp','geometry.coordinates','fields.capacity','fields.num_bikes_available','fields.num_docks_available','fields.pourcentage_de_velos_restants']]
    df1['record_timestamp']=df1.loc[:,'record_timestamp'].apply(lambda x: x.split('.')[0].replace('T',' '))
    df1[['lat','lon']]= df1['geometry.coordinates'].to_list()
    df1[['lat','lon']]=df1[['lat','lon']].astype(float)
    df1.drop('geometry.coordinates',inplace=True,axis=1)
    #tableName=dataframe
    tableName   = "df1"
    dataFrame   =df1
    dataframe   = pd.DataFrame(data = df1)
    sqlEngine       = create_engine('mysql+pymysql://zied:SAFAchaima1&@127.0.0.1/projetapi', pool_recycle=3600)
    dbConnection    = sqlEngine.connect()
    try:
        frame           = dataFrame.to_sql(tableName, dbConnection, if_exists='replace');
    except ValueError as vx:
        print(vx)
    except Exception as ex:
        print(ex)
    else:
        print("Table %s created successfully."%dataframe);
    finally:
        dbConnection.close()

# %%
load_data()
# Out:
# Table                              fields.name     record_timestamp  \
# 0                               Rondelet  2022-11-18 14:10:01
# 1                               Gambetta  2022-11-18 14:10:01
# 2                          Port Marianne  2022-11-18 14:10:01
# 3                            Les Arceaux  2022-11-18 14:10:01
# 4                                Malbosc  2022-11-18 14:10:01
# 5                   Hôtel du Département  2022-11-18 14:10:01
# 6   Parvis Jules Ferry - Gare Saint-Roch  2022-11-18 14:10:01
# 7                    Providence - Ovalie  2022-11-18 14:10:01
# 8                      Halles Castellane  2022-11-18 14:10:01
# 37                8                           7                           1
# 38                8                           4                           4
# 39               12                           2                          10
# 40               32                           6                          26
# 41               12                           5                           7
# 42               12                           4                           8
# 43               12                           1                          11
# 44                8                           6                           2
# 45                8                           4                           4
# 46                8                           4                           4
# 47               24                          13                          11
# 48               16                           4                          12
# 49               27                          15                          12
# 50                8                           4                           4
# 51                8                           1                           7
# 52               16                          16                           0
# 53                8                           4                           4
# 54                0                           0                           0
# 55                8                           5                           3
#
#     fields.pourcentage_de_velos_restants       lat        lon
# 0                              18.750000  3.875796  43.603038
# 1                              62.500000  3.870693  43.607106
# 2                              75.000000  3.898510  43.600320
# 3                              93.750000  3.867157  43.611991
# 4                              25.000000  3.832861  43.633679
# 5                              12.500000  3.834770  43.621682
# 6                              12.500000  3.879362  43.603889
# 7                              25.000000  3.853421  43.588239
# 8                              41.666667  3.877208  43.609935
# 9                              25.000000  3.890634  43.607942
# 10                             31.250000  3.893140  43.608218
# 11                             37.500000  3.875757  43.599817
# 12                             37.500000  3.865971  43.618762
# 13                             12.500000  3.849128  43.634242
# 14                             20.833333  3.860697  43.631018
# 15                             37.500000  3.882492  43.626163
# 16                             62.500000  3.883831  43.619701
# 17                             37.500000  3.873812  43.619871
# 18                             12.500000  3.860031  43.584211
# 19                             50.000000  3.832624  43.614670
# 20                             25.000000  3.911576  43.605850
# 21                             50.000000  3.880916  43.604319
# 22                             41.666667  3.873218  43.614005
# 23                             62.500000  3.872752  43.608996
# 24                             62.500000  3.923500  43.595620
# 25                             41.666667  3.881346  43.605366
# 26                             50.000000  3.873345  43.610989
# 27                             12.500000  3.876931  43.606081
# 28                             16.666667  3.868375  43.622629
# 29                             67.857143  3.884981  43.616698
# 30                             12.500000  3.893844  43.618692
# 31                             18.750000  3.886644  43.607859
# 32                             68.750000  3.877648  43.614642
# 33                             37.500000  3.875065  43.605021
# 34                             75.000000  3.888659  43.603767
# 35                              6.250000  3.870230  43.630665
# 36                             75.000000  3.828199  43.639119
# 37                             87.500000  3.855075  43.616812
# 38                             50.000000  3.839466  43.615155
# 39                             16.666667  3.882393  43.606036
# 40                             18.750000  3.881293  43.609478
# 41                             41.666667  3.881600  43.613989
# 42                             33.333333  3.868389  43.608491
# 43                              8.333333  3.872394  43.603539
# 44                             75.000000  3.884373  43.601143
# 45                             50.000000  3.867884  43.603553
# 46                             50.000000  3.890616  43.590757
# 47                             54.166667  3.878778  43.608148
# 48                             25.000000  3.894866  43.599088
# 49                             55.555556  3.873375  43.616768
# 50                             50.000000  3.879980  43.616742
# 51                             12.500000  3.918979  43.603727
# 52                            100.000000  3.899263  43.603424
# 53                             50.000000  3.884611  43.590480
# 54                                   NaN  3.868230  43.634580
# 55                             62.500000  3.855603  43.621983   created successfully.
# C:\Users\ziedj\AppData\Local\Temp\ipykernel_17308\341030953.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['record_timestamp']=df1.loc[:,'record_timestamp'].apply(lambda x: x.split('.')[0].replace('T',' '))
# C:\Users\ziedj\AppData\Local\Temp\ipykernel_17308\341030953.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[['lat','lon']]= df1['geometry.coordinates'].to_list()
# C:\Users\ziedj\AppData\Local\Temp\ipykernel_17308\341030953.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[['lat','lon']]= df1['geometry.coordinates'].to_list()
# C:\Users\ziedj\AppData\Local\Temp\ipykernel_17308\341030953.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[['lat','lon']]=df1[['lat','lon']].astype(float)
# C:\Users\ziedj\AppData\Local\Temp\ipykernel_17308\341030953.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop('geometry.coordinates',inplace=True,axis=1)
